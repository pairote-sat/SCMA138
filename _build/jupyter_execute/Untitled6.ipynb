# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Parameters
payment = 200
years = 5
interest_rate = 0.06

# Compute present value
present_value = np.sum([payment / (1 + interest_rate)**i for i in range(1, years + 1)])

# Plotting
plt.figure(figsize=(8, 4))
plt.plot([i for i in range(years + 1)], [0] + [payment]*years, marker='+', linestyle='', color='b')
for i in range(1, years + 1):
    plt.text(i, payment, f'+{payment}', verticalalignment='bottom', horizontalalignment='center')
plt.xlabel('Years')
plt.ylabel('Cash Flow ($)')
plt.title('Timeline of Annuity')
plt.xticks(np.arange(0, years + 1, 1))
plt.grid(False)  # Remove grid lines
plt.gca().yaxis.set_tick_params(size=0)  # Remove ticks on the vertical axis
plt.text(0, 0, f'$PV = {present_value:.2f}$', verticalalignment='bottom', horizontalalignment='left')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Parameters
payment = 200
years = 5
interest_rate = 0.06

# Compute present value
present_value = np.sum([payment / (1 + interest_rate)**i for i in range(1, years + 1)])

# Plotting
plt.figure(figsize=(8, 4))
plt.plot([i for i in range(years + 1)], [0] + [payment]*years, marker='o', linestyle='', color='b')
for i in range(1, years + 1):
    plt.text(i, payment, f'+{payment}', verticalalignment='bottom', horizontalalignment='center')
plt.xlabel('Years')
plt.ylabel('Cash Flow ($)')
plt.title('Timeline of Annuity')
plt.xticks(np.arange(0, years + 1, 1))
plt.grid(False)
plt.tick_params(axis='y', which='both', left=False, right=False, labelleft=False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Parameters
payment = 200
years = 5
interest_rate = 0.06

# Compute present value
present_value = np.sum([payment / (1 + interest_rate)**i for i in range(1, years + 1)])

# Plotting
plt.figure(figsize=(8, 4))
plt.plot([i for i in range(years + 1)], [0] + [payment]*years, marker='o', linestyle='', color='b')
for i in range(1, years + 1):
    plt.text(i, payment, f'+{payment}', verticalalignment='bottom', horizontalalignment='center')
plt.xlabel('Years')
plt.ylabel('Cash Flow ($)')
plt.title('Timeline of Annuity')
plt.xticks(np.arange(0, years + 1, 1))
plt.grid(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_yaxis().set_visible(False)
plt.gca().axhline(0, color='black', lw=0.5)
plt.text(0, 0, f'$PV = {present_value:.2f}$', verticalalignment='bottom', horizontalalignment='left')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Parameters
payment = 200
years = 5
interest_rate = 0.06

# Compute present value
present_value = np.sum([payment / (1 + interest_rate)**i for i in range(1, years + 1)])

# Plotting
plt.figure(figsize=(8, 4))
plt.plot([i for i in range(years + 1)], [0] + [payment]*years, marker='o', linestyle='', color='b')
for i in range(1, years + 1):
    plt.text(i, payment, f'+{payment}', verticalalignment='bottom', horizontalalignment='center')
plt.xlabel('Years')
plt.ylabel('Cash Flow ($)')
plt.title('Timeline of Annuity')
plt.xticks(np.arange(0, years + 1, 1))
plt.grid(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_yaxis().set_visible(False)
plt.text(0, 0, f'$PV = {present_value:.2f}$', verticalalignment='bottom', horizontalalignment='left')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Parameters
payment = 200
years = 5
interest_rate = 0.06

# Compute present value
present_value = np.sum([payment / (1 + interest_rate)**i for i in range(1, years + 1)])

# Plotting
plt.figure(figsize=(8, 0.8))  # Adjusted width to 2 cm
plt.plot([i for i in range(years + 1)], [0] + [payment]*years, marker='o', linestyle='', color='b')
for i in range(1, years + 1):
    plt.text(i, payment, f'+{payment}', verticalalignment='bottom', horizontalalignment='center')
plt.xlabel('Years')
plt.ylabel('Cash Flow ($)')
plt.title('Timeline of Annuity', y=1.20)  # Adding small space above the figure
plt.xticks(np.arange(0, years + 1, 1))
plt.grid(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_yaxis().set_visible(False)
plt.text(0, 0, f'$PV = {present_value:.2f}$', verticalalignment='bottom', horizontalalignment='left')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Parameters
payment = 200
years = 5
interest_rate = 0.06

# Compute present value
present_value = np.sum([payment / (1 + interest_rate)**i for i in range(1, years + 1)])

# Plotting
plt.figure(figsize=(8, 1.5))  # Adjusted width to 2 cm
plt.plot([i for i in range(years + 1)], [0] + [payment]*years, marker='o', linestyle='', color='b')
for i in range(1, years + 1):
    plt.text(i, payment + 20, f'+{payment}', verticalalignment='bottom', horizontalalignment='center')  # Adjusted y-coordinate
plt.xlabel('Years')
plt.ylabel('Cash Flow ($)')
plt.title('Timeline of Annuity', y=1.3)  # Adding small space above the figure
plt.xticks(np.arange(0, years + 1, 1))
plt.grid(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_yaxis().set_visible(False)
plt.text(0, payment + 20, f'$PV = {present_value:.2f}$', verticalalignment='bottom', horizontalalignment='left')
plt.show()

# %%
range(years + 1)
# Out:
# range(0, 6)

# %%
range(1, years + 1)
# Out:
# range(1, 6)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Parameters
payment = 200
years = 5
interest_rate = 0.06

# Compute present value
present_value = np.sum([payment / (1 + interest_rate)**i for i in range(1, years + 1)])

# Plotting
plt.figure(figsize=(8, 1.5))  # Adjusted width to 2 cm

# Adjusted x and y data to remove dot at 0
plt.plot([i for i in range(1, years + 1)], [payment]*years, marker='o', linestyle='', color='b')

# Adjusted text position
for i in range(1, years + 1):
    plt.text(i, payment + 5, f'+{payment}', verticalalignment='bottom', horizontalalignment='center')

plt.xlabel('Years')
plt.ylabel('Cash Flow ($)')
plt.title('Timeline of Annuity', y=1.3)  # Adding small space above the figure
plt.xticks(np.arange(0, years + 1, 1))
plt.grid(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_yaxis().set_visible(False)

# Adjusted text position
plt.text(0, payment + 5, f'$PV = {present_value:.2f}$', verticalalignment='bottom', horizontalalignment='left')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Parameters
investment = 500
years = 3
interest_rate = 0.08

# Compute future value
future_value = np.sum([investment * (1 + interest_rate)**i for i in range(years)])

# Plotting
plt.figure(figsize=(8, 1.5))  # Adjusted height to 2 cm
plt.plot([i for i in range(1, years + 1)], [investment]*years, marker='o', linestyle='', color='b')  # Adjusted x and y data
for i in range(1, years + 1):
    plt.text(i, investment + 10, f'+{investment}', verticalalignment='bottom', horizontalalignment='center')  # Adjusted y-coordinate
plt.xlabel('Years')
plt.ylabel('Cash Flow ($)')
plt.title('Timeline of Future Value Annuity', y=1.3)  # Adding small space above the figure
plt.xticks(np.arange(0, years + 1, 1))  # Adjusted x ticks
plt.grid(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_yaxis().set_visible(False)
plt.text(3, investment + 25, f'$FV = {future_value:.2f}$', verticalalignment='bottom', horizontalalignment='left')  # Adjusted x-coordinate
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Parameters
investment = 100
interest_rate = 0.12
years = 1

# Compute future value
future_value = investment * (1 + interest_rate)

# Plotting
plt.figure(figsize=(8, 1.5))  # Adjusted height to 2 cm
plt.plot([i for i in range(1, years + 1)], [investment]*years, marker='o', linestyle='', color='b')  # Adjusted x and y data
for i in range(1, years + 1):
    plt.text(i, investment + 5, f'+{investment}', verticalalignment='bottom', horizontalalignment='center')  # Adjusted y-coordinate
plt.xlabel('Years')
plt.ylabel('Cash Flow ($)')
plt.title('Timeline of Example 3.11', y=1.3)  # Adding small space above the figure
plt.xticks(np.arange(1, years + 1, 1))  # Adjusted x ticks
plt.grid(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_yaxis().set_visible(False)
plt.text(1, investment + 7, f'$FV = {future_value:.2f}$', verticalalignment='bottom', horizontalalignment='left')  # Adjusted x-coordinate
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Parameters
investment = 100
interest_rate = 0.12
years = 1

# Compute future value
future_value = investment * (1 + interest_rate)

# Plotting
plt.figure(figsize=(8, 1.5))  # Adjusted height to 2 cm
plt.plot([0], [investment], marker='o', linestyle='', color='b')  # Adjusted x and y data
plt.text(0, investment + 5, f'+{investment}', verticalalignment='bottom', horizontalalignment='center')  # Adjusted y-coordinate
plt.xlabel('Years')
plt.ylabel('Cash Flow ($)')
plt.title('Timeline of Example 3.11', y=1.3)  # Adding small space above the figure
plt.xticks(np.arange(0, years + 1, 1))  # Adjusted x ticks
plt.grid(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_yaxis().set_visible(False)
plt.text(1, investment + 5, f'$FV = {future_value:.2f}$', verticalalignment='bottom', horizontalalignment='left')  # Adjusted x-coordinate
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Parameters
investment = 100
interest_rate_annual = 0.12
compounding_periods_per_year = 4
years = 1

# Compute future value
interest_rate_quarterly = interest_rate_annual / compounding_periods_per_year
future_value = investment * (1 + interest_rate_quarterly)**(compounding_periods_per_year * years)

# Plotting
plt.figure(figsize=(8, 1.5))  # Adjusted height to 2 cm
plt.plot([0], [investment], marker='o', linestyle='', color='b')  # Adjusted x and y data
plt.text(0, investment + 5, f'+{investment}', verticalalignment='bottom', horizontalalignment='center')  # Adjusted y-coordinate
plt.xlabel('Years')
plt.ylabel('Cash Flow ($)')
plt.title('Timeline of Example 3.11', y=1.3)  # Adding small space above the figure
plt.xticks(np.arange(0, years + 1, 1))  # Adjusted x ticks
plt.grid(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_yaxis().set_visible(False)
plt.text(0.5, investment + 5, 'i = 0.12 per year (compounded quarterly)', verticalalignment='bottom', horizontalalignment='center')  # Text at x=0.5
plt.text(1, investment + 5, f'$FV = {future_value:.2f}$', verticalalignment='bottom', horizontalalignment='left')  # Adjusted x-coordinate
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Parameters
investment = 100
interest_rate_annual = 0.12
compounding_periods_per_year = 4
years = 1

# Compute future value
interest_rate_quarterly = interest_rate_annual / compounding_periods_per_year
future_value = investment * (1 + interest_rate_quarterly)**(compounding_periods_per_year * years)

# Plotting
plt.figure(figsize=(8, 1.5))  # Adjusted height to 2 cm
plt.plot([0], [investment], marker='o', linestyle='', color='b')  # Adjusted x and y data
plt.text(0, investment + 5, f'+{investment}', verticalalignment='bottom', horizontalalignment='center')  # Adjusted y-coordinate
plt.xlabel('Years')
plt.ylabel('Cash Flow ($)')
plt.title('Timeline of Example 3.11', y=1.3)  # Adding small space above the figure
plt.xticks(np.arange(0, years + 1/4, 1/4))  # Adjusted x ticks
plt.grid(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().get_yaxis().set_visible(False)
plt.text(0.5, investment + 5, 'i = 0.03 per quarter', verticalalignment='bottom', horizontalalignment='center')  # Text at x=0.5
plt.text(1, investment + 5, f'$FV = {future_value:.2f}$', verticalalignment='bottom', horizontalalignment='left')  # Adjusted x-coordinate
plt.show()
